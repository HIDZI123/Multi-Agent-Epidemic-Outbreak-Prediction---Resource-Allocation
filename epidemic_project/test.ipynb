# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

print("Jupyter is working!")
print("Ready to build our epidemic simulation!")

# Test plot (will display right in the notebook!)
x = [1, 2, 3, 4, 5]
y = [2, 4, 6, 8, 10]
plt.figure(figsize=(8, 5))
plt.plot(x, y, 'bo-', linewidth=2, markersize=8)
plt.title("Jupyter Test - Success!")
plt.grid(True, alpha=0.3)
plt.show()
# Out:
# Jupyter is working!
# Ready to build our epidemic simulation!
